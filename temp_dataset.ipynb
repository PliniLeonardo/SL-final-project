# %%
import pandas as pd

# %%
soil = pd.read_csv('soil_data.csv')

# %%
lg = pd.read_csv('longitudine-latitudine.csv')

# %%
soil.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      id                              name  \
# 0         264           264  137591                     Citra, Merlot
# 1         371           371  137738             Geografico, Pulleraia
# 2         481           481  137960       Castello di Ama, L'Apparita
# 3         630           630  138381                           Masseto
# 4        1290          1290  139447  Folonari, Bolgheri Campo Al Mare
#
#                               producer nation   local1    local2  local3  \
# 0                                Citra  Italy      NaN       NaN     NaN
# 1                           Geografico  Italy  Toscana       NaN     NaN
# 2                      Castello di Ama  Italy  Toscana       NaN     NaN
# 3                            Ornellaia  Italy  Toscana       NaN     NaN
# 4  Tenute Ambrogio e Giovanni Folonari  Italy  Toscana  Bolgheri     NaN
#
#    local4  ...   ml latitudine longitudine    cec   cfvo   clay  nitrogen  \
# ...

# %%
lg.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      id                         name  \
# 0         187           187  137432      Santa Margherita Merlot
# 1         264           264  137591                Citra, Merlot
# 2         371           371  137738        Geografico, Pulleraia
# 3         481           481  137960  Castello di Ama, L'Apparita
# 4         630           630  138381                      Masseto
#
#            producer nation   local1 local2  local3  local4  ...   ml  \
# 0  Santa Margherita  Italy   Veneto    NaN     NaN     NaN  ...  750
# 1             Citra  Italy      NaN    NaN     NaN     NaN  ...  750
# 2        Geografico  Italy  Toscana    NaN     NaN     NaN  ...  750
# 3   Castello di Ama  Italy  Toscana    NaN     NaN     NaN  ...  750
# 4         Ornellaia  Italy  Toscana    NaN     NaN     NaN  ...  750
#
#   latitudine longitudine   cec  cfvo  clay  nitrogen  phh2o  sand  silt
# 0  45.768172   12.902619   NaN   NaN   NaN       NaN    NaN   NaN   NaN
# ...

# %%
soil.shape
# Out:
# (121, 42)

# %%
lg.shape
# Out:
# (166, 42)

# %%
soil[['id', 'latitudine', 'longitudine']].isna().sum()
# Out:
# id             0
# latitudine     0
# longitudine    0
# dtype: int64

# %%
lg[['id', 'latitudine', 'longitudine']].isna().sum()
# Out:
# id             0
# latitudine     0
# longitudine    0
# dtype: int64

# %%
len(soil['id'].unique())
# Out:
# 121

# %%
len(lg['id'].unique())
# Out:
# 166

# %%
missing_id = list(set(lg['id'].unique()) - set(soil['id'].unique()))

# %%
missing_id
# Out:
# [146055,
#  146823,
#  147593,
#  162186,
#  147339,
#  167437,
#  158862,
#  148626,
#  153492,
#  152473,
#  147226,
#  158747,
#  147357,
#  147358,
#  140831,
#  140832,
#  153121,
#  164766,
#  150947,
#  167076,
#  150948,
#  151719,
#  165756,
#  155178,
#  153131,
#  166058,
#  139311,
#  139312,
#  152623,
#  161459,
#  145590,
#  141885,
#  154056,
#  152528,
#  161492,
#  164310,
#  143447,
#  137432,
#  143449,
#  146905,
#  144863,
#  138600,
#  154611,
#  160245,
#  144636]

# %%
newdf = lg[lg['id'].isin(missing_id)]

# %%
with open('lat_long_new.csv', 'w') as f:
    f.write('id, lat, long \n')
    for id in newdf['id'].to_list():
        f.write(str(id) + ', \n')

# %%
newdf
# Out:
#      Unnamed: 0  Unnamed: 0.1      id  \
# 0           187           187  137432
# 5           763           763  138600
# 6          1189          1189  139311
# 7          1190          1190  139312
# 22         2207          2207  140831
# 23         2208          2208  140832
# 28         2844          2844  141885
# 33         3470          3470  143447
# 34         3472          3472  143449
# 35         3889          3889  144636
# 38         3983          3983  144863
# 42         4495          4495  145590
# 43         4899          4899  146055
# 46         5558          5558  146823
# 48         5630          5630  146905
# 52         5887          5887  147226
# 57         5972          5972  147339
# 58         5989          5989  147357
# 59         5990          5990  147358
# 61         6193          6193  147593
# 63         7016          7016  148626
# 72         9056          9056  150947
# 73         9057          9057  150948
# ...
